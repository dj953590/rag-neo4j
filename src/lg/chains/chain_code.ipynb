# %%
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain.chains import LLMChain
from dynaconf import settings
from langchain.globals import set_debug

set_debug(True)

# the file is about how to use prompt in langchain groq
# Set up your GROQ API key
api_groq_key = settings.GROQ_API_KEY

# %%
TEMPLATE = """
Interprete the text and evaluate the text.
sentiment: is the text in a positive, neutral or negative sentiment? Sentiment is required.
subject: What subject is the text about? Use exactly one word. Use 'None' if no subject was provided. here the subject is proper noun in the sentence.
price: How much did the customer pay? Use 'None' if no price was provided and user currency symbol instead of text.

Format the output as JSON with the following keys:
sentiment
subject
price

text: {input}
"""

# %%
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
from rich import print as rprint


llm = ChatGroq(temperature=0.0, model_name=f"llama-3.1-70b-versatile", api_key=api_groq_key)

prompt_template = ChatPromptTemplate.from_template(TEMPLATE)
llm_chain = LLMChain(llm=llm, prompt=prompt_template)

response = llm_chain.run(input="I ordered pizza salami I had a great time at the Dominos pizza. The pizza was delicious, and the service was friendly. it costed me about 25 dollars with tips")

rprint(response)
# Out:
# [chain/start] [chain:LLMChain] Entering Chain run with input:
# {
#   "input": "I ordered pizza salami I had a great time at the Dominos pizza. The pizza was delicious, and the service was friendly. it costed me about 25 dollars with tips"
# }
# [llm/start] [chain:LLMChain > llm:ChatGroq] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \nInterprete the text and evaluate the text.\nsentiment: is the text in a positive, neutral or negative sentiment? Sentiment is required.\nsubject: What subject is the text about? Use exactly one word. Use 'None' if no subject was provided. here the subject is proper noun in the sentence.\nprice: How much did the customer pay? Use 'None' if no price was provided and user currency symbol instead of text.\n\nFormat the output as JSON with the following keys:\nsentiment\nsubject\nprice\n\ntext: I ordered pizza salami I had a great time at the Dominos pizza. The pizza was delicious, and the service was friendly. it costed me about 25 dollars with tips"
#   ]
# }
# [llm/end] [chain:LLMChain > llm:ChatGroq] s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "```json\n{\n  \"sentiment\": \"positive\",\n  \"subject\": \"Dominos\",\n  \"price\": \"$25\"\n}\n```",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "```json\n{\n  \"sentiment\": \"positive\",\n  \"subject\": \"Dominos\",\n  \"price\": \"$25\"\n}\n```",
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 30,
#                 "prompt_tokens": 182,
#                 "total_tokens": 212,
#                 "completion_time": 0.12,
#                 "prompt_time": 0.019872258,
#                 "queue_time": 0.028427473999999998,
#                 "total_time": 0.139872258
#               },
#               "model_name": "llama-3.1-70b-versatile",
#               "system_fingerprint": "fp_1c3737e28c",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "run-e3c0270e-ac8c-4867-8879-06a24a75af77-0",
#             "usage_metadata": {
#               "input_tokens": 182,
#               "output_tokens": 30,
#               "total_tokens": 212
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 30,
#       "prompt_tokens": 182,
#       "total_tokens": 212,
#       "completion_time": 0.12,
#       "prompt_time": 0.019872258,
#       "queue_time": 0.028427473999999998,
#       "total_time": 0.139872258
#     },
#     "model_name": "llama-3.1-70b-versatile",
#     "system_fingerprint": "fp_1c3737e28c"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:LLMChain] s] Exiting Chain run with output:
# {
#   "text": "```json\n{\n  \"sentiment\": \"positive\",\n  \"subject\": \"Dominos\",\n  \"price\": \"$25\"\n}\n```"
# }
# ```json
# {
#   "sentiment": "positive",
#   "subject": "Dominos",
#   "price": "$25"
# }
# ```

# %%
COFFEE_CHAIN_TEMPLATE = """
Give me numbered list of all coffee-related world in English from the text below and also convert those words and list them in numbered list in other language.
The Task requires the following action L
1 - Transalate the fgiven text to Englist
2 - List each coffee-related word from the text 
3 - List each coffee-related word in the translated language

Format the output as List with the following keys:

text: {input}
target_language: {target_language}
"""

# %%
coffee_chain_template = ChatPromptTemplate.from_template(COFFEE_CHAIN_TEMPLATE)
llm_chain = LLMChain(llm=llm, prompt=coffee_chain_template)

response = llm_chain.run(input="Preparing Cold Brew coffee is simple and easy process! All you need is coarse ground coffee beans and cold water.", target_language="French")

rprint(response)
# Out:
# [chain/start] [chain:LLMChain] Entering Chain run with input:
# {
#   "input": "Preparing Cold Brew coffee is simple and easy process! All you need is coarse ground coffee beans and cold water.",
#   "target_language": "French"
# }
# [llm/start] [chain:LLMChain > llm:ChatGroq] Entering LLM run with input:
# {
#   "prompts": [
#     "Human: \nGive me numbered list of all coffee-related world in English from the text below and also convert those words and list them in numbered list in other language.\nThe Task requires the following action L\n1 - Transalate the fgiven text to Englist\n2 - List each coffee-related word from the text \n3 - List each coffee-related word in the translated language\n\nFormat the output as List with the following keys:\n\ntext: Preparing Cold Brew coffee is simple and easy process! All you need is coarse ground coffee beans and cold water.\ntarget_language: French"
#   ]
# }
# [llm/end] [chain:LLMChain > llm:ChatGroq] [1.32s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "**English List:**\n\n1. Coffee\n2. Brew\n3. Ground\n4. Beans\n5. Cold Brew (considered as a single term)\n\n**French List:**\n\n1. Café\n2. Infusion (Note: 'Brew' can be translated to 'Infusion' in French for coffee context)\n3. Moulue (Note: 'Ground' can be translated to 'Moulue' in French for coffee context)\n4. Fèves (Note: 'Beans' can be translated to 'Fèves' in French for coffee context)\n5. Café Froid (Note: 'Cold Brew' can be translated to 'Café Froid' in French)\n\n**Output:**\n\n- text: Preparing Cold Brew coffee is simple and easy process! All you need is coarse ground coffee beans and cold water.\n- target_language: French\n- english_list: \n  1. Coffee\n  2. Brew\n  3. Ground\n  4. Beans\n  5. Cold Brew\n- french_list: \n  1. Café\n  2. Infusion\n  3. Moulue\n  4. Fèves\n  5. Café Froid",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "**English List:**\n\n1. Coffee\n2. Brew\n3. Ground\n4. Beans\n5. Cold Brew (considered as a single term)\n\n**French List:**\n\n1. Café\n2. Infusion (Note: 'Brew' can be translated to 'Infusion' in French for coffee context)\n3. Moulue (Note: 'Ground' can be translated to 'Moulue' in French for coffee context)\n4. Fèves (Note: 'Beans' can be translated to 'Fèves' in French for coffee context)\n5. Café Froid (Note: 'Cold Brew' can be translated to 'Café Froid' in French)\n\n**Output:**\n\n- text: Preparing Cold Brew coffee is simple and easy process! All you need is coarse ground coffee beans and cold water.\n- target_language: French\n- english_list: \n  1. Coffee\n  2. Brew\n  3. Ground\n  4. Beans\n  5. Cold Brew\n- french_list: \n  1. Café\n  2. Infusion\n  3. Moulue\n  4. Fèves\n  5. Café Froid",
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 259,
#                 "prompt_tokens": 149,
#                 "total_tokens": 408,
#                 "completion_time": 1.036,
#                 "prompt_time": 0.02808221,
#                 "queue_time": 0.0035060249999999994,
#                 "total_time": 1.06408221
#               },
#               "model_name": "llama-3.1-70b-versatile",
#               "system_fingerprint": "fp_9260b4bb2e",
#               "finish_reason": "stop",
#               "logprobs": null
#             },
#             "type": "ai",
#             "id": "run-4ab18187-8335-4ad9-aea5-f2fe58e6bfd7-0",
#             "usage_metadata": {
#               "input_tokens": 149,
#               "output_tokens": 259,
#               "total_tokens": 408
#             },
#             "tool_calls": [],
#             "invalid_tool_calls": []
#           }
#         }
#       }
#     ]
#   ],
#   "llm_output": {
#     "token_usage": {
#       "completion_tokens": 259,
#       "prompt_tokens": 149,
#       "total_tokens": 408,
#       "completion_time": 1.036,
#       "prompt_time": 0.02808221,
#       "queue_time": 0.0035060249999999994,
#       "total_time": 1.06408221
#     },
#     "model_name": "llama-3.1-70b-versatile",
#     "system_fingerprint": "fp_9260b4bb2e"
#   },
#   "run": null,
#   "type": "LLMResult"
# }
# [chain/end] [chain:LLMChain] [1.32s] Exiting Chain run with output:
# {
#   "text": "**English List:**\n\n1. Coffee\n2. Brew\n3. Ground\n4. Beans\n5. Cold Brew (considered as a single term)\n\n**French List:**\n\n1. Café\n2. Infusion (Note: 'Brew' can be translated to 'Infusion' in French for coffee context)\n3. Moulue (Note: 'Ground' can be translated to 'Moulue' in French for coffee context)\n4. Fèves (Note: 'Beans' can be translated to 'Fèves' in French for coffee context)\n5. Café Froid (Note: 'Cold Brew' can be translated to 'Café Froid' in French)\n\n**Output:**\n\n- text: Preparing Cold Brew coffee is simple and easy process! All you need is coarse ground coffee beans and cold water.\n- target_language: French\n- english_list: \n  1. Coffee\n  2. Brew\n  3. Ground\n  4. Beans\n  5. Cold Brew\n- french_list: \n  1. Café\n  2. Infusion\n  3. Moulue\n  4. Fèves\n  5. Café Froid"
# }
# **English List:**
#
# 1. Coffee
# 2. Brew
# 3. Ground
# 4. Beans
# 5. Cold Brew (considered as a single term)
#
# **French List:**
#
# 1. Café
# 2. Infusion (Note: 'Brew' can be translated to 'Infusion' in French for coffee context)
# 3. Moulue (Note: 'Ground' can be translated to 'Moulue' in French for coffee context)
# 4. Fèves (Note: 'Beans' can be translated to 'Fèves' in French for coffee context)
# 5. Café Froid (Note: 'Cold Brew' can be translated to 'Café Froid' in French)
#
# **Output:**
#
# - text: Preparing Cold Brew coffee is simple and easy process! All you need is coarse ground coffee beans and cold
# water.
# - target_language: French
# - english_list:
#   1. Coffee
#   2. Brew
#   3. Ground
#   4. Beans
#   5. Cold Brew
# - french_list:
#   1. Café
#   2. Infusion
#   3. Moulue
#   4. Fèves
#   5. Café Froid
